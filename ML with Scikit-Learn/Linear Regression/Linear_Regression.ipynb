# %%
import pandas as pd
import numpy as np
df=pd.read_csv('data.csv')
df
# Out:
#     32.502345269453031  31.70700584656992
# 0            53.426804          68.777596
# 1            61.530358          62.562382
# 2            47.475640          71.546632
# 3            59.813208          87.230925
# 4            55.142188          78.211518
# 5            52.211797          79.641973
# 6            39.299567          59.171489
# 7            48.105042          75.331242
# 8            52.550014          71.300880
# 9            45.419730          55.165677
# 10           54.351635          82.478847
# 11           44.164049          62.008923
# 12           58.168471          75.392870
# 13           56.727208          81.436192
# 14           48.955889          60.723602
# 15           44.687196          82.892504
# 16           60.297327          97.379897
# 17           45.618644          48.847153
# 18           38.816818          56.877213
# 19           66.189817          83.878565
# 20           65.416052         118.591217
# ...

# %%
df_train=df[0:70]
df_test=df[71:98]
#Data should be converted into numpy array 
df_train_X=np.array(df_train[df_train.columns[0]]).reshape(70,1)
df_train_Y=np.array(df_train[df_train.columns[1]]).reshape(70,1)
df_test_X=np.array(df_test[df_test.columns[0]]).reshape(27,1)
df_test_Y=np.array(df_test[df_train.columns[1]]).reshape(27,1)
df_train_Y ##Before feed the data into model you have format the data in this shape
# Out:
# array([[ 68.77759598],
#        [ 62.5623823 ],
#        [ 71.54663223],
#        [ 87.23092513],
#        [ 78.21151827],
#        [ 79.64197305],
#        [ 59.17148932],
#        [ 75.3312423 ],
#        [ 71.30087989],
#        [ 55.16567715],
#        [ 82.47884676],
#        [ 62.00892325],
#        [ 75.39287043],
#        [ 81.43619216],
#        [ 60.72360244],
#        [ 82.89250373],
#        [ 97.37989686],
#        [ 48.84715332],
#        [ 56.87721319],
#        [ 83.87856466],
#        [118.5912173 ],
#        [ 57.25181946],
#        [ 51.39174408],
#        [ 75.38065167],
#        [ 74.76556403],
#        [ 95.45505292],
#        [ 95.22936602],
#        [ 79.05240617],
#        [ 83.43207142],
#        [ 63.35879032],
#        [ 41.4128853 ],
#        [ 76.61734128],
#        [ 96.76956643],
#        [ 74.08413012],
#        [ 66.58814441],
#        [ 77.76848242],
#        [ 50.71958891],
#        [ 62.12457082],
#        [ 60.81024665],
#        [ 52.68298337],
# ...

# %%
## Starting MSE
I_MSE=0 
for i in range(len(df_train_X)):
    I_MSE+=(df_train_X[0])**2/(2*len(df_train_X))
print("Initial Mean Square Error: ",I_MSE[0])

#plot the training set
plt.scatter(df_train_X,df_train_Y,  color='red')
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Initial Mean Square Error:  1427.2116946049855

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

regr = linear_model.LinearRegression()

regr.fit(df_train_X, df_train_Y)

df_y_pred = regr.predict(df_test_X)

print("Mean squared error: %.2f"
      % mean_squared_error(df_test_Y, df_y_pred))

# Plot outputs
plt.scatter(df_test_X,df_test_Y,  color='red')
plt.plot(df_test_X, df_y_pred, color='green', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Mean squared error: 93.55
